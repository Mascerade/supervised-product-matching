# %%
import pandas as pd
import os
import numpy as np
import random
from tqdm import tqdm
from src.preprocessing import remove_stop_words
from src.common import create_final_data, Common

# %%
class LaptopAttributes():
    '''
    Different from LaptopAttributes, this is specific for creating spec data.
    The spec data was gathered from PCPartPicker and is used to create more laptop data.
    '''

    video_card = {'GeForce RTX 2070'}
    ram = [str(x) + ' GB' for x in range(2, 130, 2)]
    hard_drive = [str(x) + ' GB' for x in range(120, 513, 8)] + [str(x) + ' TB' for x in range(1, 8)]
    cpu = {}
    laptop_brands = ['Lenovo ThinkPad', 'Lenovo ThinkBook', 'Lenovo IdeaPad', 'Lenovo Yoga', 'Lenovo Legion', 'HP Envy', 'HP Chromebook', 'HP Spectre', 'HP ZBook', 'HP Probook', 'HP Elitebook', 'HP Pavilion', 'HP Omen', 'Dell Alienware', 'Dell Vostro', 'Dell Inspiron', 'Dell Latitude', 'Dell XPS', 'Dell G Series', 'Dell Precision', 'Apple Macbook', 'Apple Macbook Air', 'Apple Mac', 'Acer Aspire', 'Acer Swift', 'Acer Spin', 'Acer Switch', 'Acer Extensa', 'Acer Travelmate', 'Acer Nitro', 'Acer Enduro', 'Acer Predator', 'Asus ZenBook', 'Asus Vivobook', 'Asus Republic of Gamers', 'Asus ROG', 'Asus TUF GAMING']
    screen = {'1440x900'}
    inches = {'13.3'}
    
    @staticmethod
    def get_all_data():
        return {
            'cpu': LaptopAttributes.cpu.keys(),
            'ram': LaptopAttributes.ram,
            'hard_drive': LaptopAttributes.hard_drive,
            'video_card': LaptopAttributes.video_card,
            'laptop_brands': LaptopAttributes.laptop_brands
        }

# %%
def populate_spec():
    '''
    Creates a string out of the row of product attributes (so row is a Pandas DataFrame).
    '''

    # Getting the CPU data into SpecAttrbutes
    cpu_df = pd.read_csv('data/train/cpu_data.csv')
    temp_iloc = cpu_df.iloc()
    for idx in range(len(cpu_df)):
        row = temp_iloc[idx]
        LaptopAttributes.cpu[row['name']] = [row['cores'], row['core_clock']]

    # Getting the video card data into SpecAttributes
    video_card_df = pd.read_csv('data/train/video-cards-data.csv')
    temp_iloc = video_card_df.iloc()
    for idx in range(len(video_card_df)):
        row = temp_iloc[idx]
        LaptopAttributes.video_card.update([row['chipset']])
    
    laptops_df = pd.read_csv('data/train/laptops.csv', encoding='latin-1')
    LaptopAttributes.inches.update([str(row.Inches) for row in laptops_df[['Inches']].itertuples()])
    LaptopAttributes.screen.update([row.ScreenResolution for row in laptops_df[['ScreenResolution']].itertuples()])
    LaptopAttributes.video_card.update([row.Gpu for row in laptops_df[['Gpu']].itertuples()]) 
    
    for row in laptops_df.iloc:
        if row.Company != 'Apple':
            LaptopAttributes.cpu[' '.join(row.Cpu.split(' ')[:-1])] = [None, row.Cpu.split(' ')[-1]]

# %%
populate_spec()

# %%
LaptopAttributes.cpu
# Out:
# {'AMD Ryzen 5 3600': [6, '3.6 GHz'],
#  'AMD Ryzen 7 3700X': [8, '3.6 GHz'],
#  'AMD Ryzen 5 2600': [6, '3.4 GHz'],
#  'AMD Ryzen 9 3900X': [12, '3.8 GHz'],
#  'AMD Ryzen 3 3200G': [4, '3.6 GHz'],
#  'AMD Ryzen 5 3600X': [6, '3.8 GHz'],
#  'Intel Core i7-9700K': [8, '3.6 GHz'],
#  'Intel Core i5-9600K': [6, '3.7 GHz'],
#  'Intel Core i9-10900K': [10, '3.7 GHz'],
#  'Intel Core i9-9900K': [8, '3.6 GHz'],
#  'AMD Ryzen 7 3800X': [8, '3.9 GHz'],
#  'AMD Ryzen 5 1600 (12nm)': [6, '3.2 GHz'],
#  'AMD Ryzen 9 3950X': [16, '3.5 GHz'],
#  'Intel Core i7-10700K': [8, '3.8 GHz'],
#  'AMD Ryzen 7 2700X': [8, '3.7 GHz'],
#  'Intel Core i3-9100F': [4, '3.6 GHz'],
#  'AMD Ryzen 3 3100': [4, '3.6 GHz'],
#  'AMD Ryzen 5 3400G': [4, '3.7 GHz'],
#  'Intel Core i5-9400F': [6, '2.9 GHz'],
#  'Intel Core i5-10600K': [6, '4.1 GHz'],
#  'AMD Ryzen 3 3300X': [4, '3.8 GHz'],
#  'AMD Threadripper 3990X': [64, '2.9 GHz'],
#  'AMD Ryzen 5 2600X': [6, '3.6 GHz'],
#  'Intel Core i7-8700K': [6, '3.7 GHz'],
#  'Intel Core i5-9400': [6, '2.9 GHz'],
#  'Intel Core i5-10400': [6, '2.9 GHz'],
#  'AMD Ryzen 3 1200 (14nm)': [4, '3.1 GHz'],
#  'AMD Ryzen 9 3900XT': [12, '3.8 GHz'],
#  'AMD Athlon 3000G': [2, '3.5 GHz'],
#  'Intel Core i7-6700K': [4, '4 GHz'],
#  'Intel Core i7-10700': [8, '2.9 GHz'],
#  'AMD Ryzen 5 3600XT': [6, '3.8 GHz'],
#  'AMD Ryzen 3 2200G': [4, '3.5 GHz'],
#  'Intel Core i3-10100': [4, '3.6 GHz'],
#  'AMD Threadripper 3970X': [32, '3.7 GHz'],
#  'AMD Ryzen 7 2700': [8, '3.2 GHz'],
#  'Intel Core i7-8700': [6, '3.2 GHz'],
#  'AMD Ryzen 7 3800XT': [8, '3.9 GHz'],
#  'Intel Core i7-9700': [8, '3 GHz'],
#  'AMD Threadripper 3960X': [24, '3.8 GHz'],
#  'Intel Xeon E5-2690 V4': [14, '2.6 GHz'],
#  'Intel Core i7-9700F': [8, '3 GHz'],
#  'Intel Core i3-9100': [4, '3.6 GHz'],
#  'Intel Core i7-7700K': [4, '4.2 GHz'],
#  'Intel Core i5-9600KF': [6, '3.7 GHz'],
#  'Intel Core i5-8400': [6, '2.8 GHz'],
#  'Intel Core i5-10600KF': [6, '4.1 GHz'],
#  'Intel Core i5-6600K': [4, '3.5 GHz'],
#  'Intel Core i5-8600K': [6, '3.6 GHz'],
#  'Intel Core i9-10980XE': [18, '3 GHz'],
#  'AMD Ryzen 5 1600 (14nm)': [6, '3.2 GHz'],
#  'Intel Core i9-9900KS': [8, '4 GHz'],
#  'Intel Core 2 Duo E7300': [2, '2.66 GHz'],
#  'Intel Core i7-4790K': [4, '4 GHz'],
#  'AMD Athlon 200GE': [2, '3.2 GHz'],
#  'Intel Core i7-7700': [4, '3.6 GHz'],
#  'Intel Core i5-10400F': [6, '2.9 GHz'],
#  'Intel Core i3-8100': [4, '3.6 GHz'],
#  'Intel Core i5-3470': [4, '3.2 GHz'],
#  'AMD Ryzen 5 2400G': [4, '3.6 GHz'],
#  'Intel Pentium Gold G5400': [2, '3.7 GHz'],
#  'AMD Ryzen 3 1200 (12nm)': [4, '3.1 GHz'],
#  'Intel Core i5-7400': [4, '3 GHz'],
#  'Intel Core i9-9900': [8, '3.1 GHz'],
#  'Intel Core i5-4690K': [4, '3.5 GHz'],
#  'AMD FX-6300': [6, '3.5 GHz'],
#  'AMD Threadripper 1920X': [12, '3.5 GHz'],
#  'AMD Threadripper 1900X': [8, '3.8 GHz'],
#  'AMD Ryzen 7 1700': [8, '3 GHz'],
#  'Intel Core i7-6700': [4, '3.4 GHz'],
#  'Intel Core i9-9900KF': [8, '3.6 GHz'],
#  'AMD FX-8350': [8, '4 GHz'],
#  'Intel Core i7-3770': [4, '3.4 GHz'],
#  'Intel Core i5-6500': [4, '3.2 GHz'],
#  'Intel Core i5-10600': [6, '3.3 GHz'],
#  'Intel Core i7-4770K': [4, '3.5 GHz'],
#  'Intel Core i9-10900X': [10, '3.7 GHz'],
#  'Intel Core i9-10900': [10, '2.8 GHz'],
#  'AMD Ryzen 5 3500': [6, '3.6 GHz'],
#  'Intel Core i5-7500': [4, '3.4 GHz'],
#  'Intel Core i7-9700KF': [8, '3.6 GHz'],
#  'Intel Core i5-2400': [4, '3.1 GHz'],
#  'Intel Core i5-7600K': [4, '3.8 GHz'],
#  'Intel Core i5-4460': [4, '3.2 GHz'],
#  'AMD Ryzen 7 1700X': [8, '3.4 GHz'],
#  'Intel Core i3-2100': [2, '3.1 GHz'],
#  'AMD Ryzen 5 3500X': [6, '3.6 GHz'],
#  'AMD Ryzen 5 1400': [4, '3.2 GHz'],
#  'Intel Core i5-10500': [6, '3.1 GHz'],
#  'Intel Core i5-6400': [4, '2.7 GHz'],
#  'Intel Core i9-10900KF': [10, '3.7 GHz'],
#  'AMD Ryzen 5 1600X': [6, '3.6 GHz'],
#  'Intel Core i5-4590': [4, '3.3 GHz'],
#  'Intel Core i7-4790': [4, '3.6 GHz'],
#  'Intel Core i7-2600': [4, '3.4 GHz'],
#  'AMD FX-9590': [8, '4.7 GHz'],
#  'Intel Core i7-10700KF': [8, '3.8 GHz'],
#  'Intel Core i5 7200U': [None, '2.5GHz'],
#  'AMD A9-Series 9420': [None, '3GHz'],
#  'Intel Core i7 8550U': [None, '1.8GHz'],
#  'Intel Core i5 8250U': [None, '1.6GHz'],
#  'Intel Core i3 6006U': [None, '2GHz'],
#  'Intel Core i7 7500U': [None, '2.7GHz'],
#  'Intel Core i3 7100U': [None, '2.4GHz'],
#  'Intel Atom x5-Z8350': [None, '1.44GHz'],
#  'Intel Core i5 7300HQ': [None, '2.5GHz'],
#  'AMD E-Series E2-9000e': [None, '1.5GHz'],
#  'Intel Core i7 8650U': [None, '1.9GHz'],
#  'Intel Atom x5-Z8300': [None, '1.44GHz'],
#  'AMD E-Series E2-6110': [None, '1.5GHz'],
#  'AMD A6-Series 9220': [None, '2.5GHz'],
#  'Intel Celeron Dual Core N3350': [None, '1.1GHz'],
#  'Intel Core i3 7130U': [None, '2.7GHz'],
#  'Intel Core i7 7700HQ': [None, '2.8GHz'],
#  'AMD Ryzen 1700': [None, '3GHz'],
#  'Intel Pentium Quad Core N4200': [None, '1.1GHz'],
#  'Intel Atom x5-Z8550': [None, '1.44GHz'],
#  'Intel Celeron Dual Core N3060': [None, '1.6GHz'],
#  'AMD FX 9830P': [None, '3GHz'],
#  'Intel Core i7 7560U': [None, '2.4GHz'],
#  'AMD E-Series 6110': [None, '1.5GHz'],
#  'Intel Core i5 6200U': [None, '2.3GHz'],
#  'Intel Core M 6Y75': [None, '1.2GHz'],
#  'Intel Core i5 7500U': [None, '2.7GHz'],
#  'Intel Core i7 6920HQ': [None, '2.9GHz'],
#  'Intel Core i5 7Y54': [None, '1.2GHz'],
#  'Intel Core i7 7820HK': [None, '2.9GHz'],
#  'Intel Xeon E3-1505M V6': [None, '3GHz'],
#  'Intel Core i7 6500U': [None, '2.5GHz'],
#  'AMD E-Series 9000e': [None, '1.5GHz'],
#  'AMD A10-Series A10-9620P': [None, '2.5GHz'],
#  'AMD A6-Series A6-9220': [None, '2.5GHz'],
#  'Intel Core i7 6600U': [None, '2.6GHz'],
#  'Intel Celeron Dual Core 3205U': [None, '1.5GHz'],
#  'Intel Core i7 7820HQ': [None, '2.9GHz'],
#  'AMD A10-Series 9600P': [None, '2.4GHz'],
#  'Intel Core i7 7600U': [None, '2.8GHz'],
#  'AMD A8-Series 7410': [None, '2.2GHz'],
#  'Intel Celeron Dual Core 3855U': [None, '1.6GHz'],
#  'Intel Pentium Quad Core N3710': [None, '1.6GHz'],
#  'AMD A12-Series 9720P': [None, '3.6GHz'],
#  'Intel Core i5 7300U': [None, '2.6GHz'],
#  'Intel Celeron Quad Core N3450': [None, '1.1GHz'],
#  'Intel Core i5 6440HQ': [None, '2.6GHz'],
#  'Intel Core i7 6820HQ': [None, '2.7GHz'],
#  'AMD Ryzen 1600': [None, '3.2GHz'],
#  'Intel Core i7 7Y75': [None, '1.3GHz'],
#  'Intel Core i5 7440HQ': [None, '2.8GHz'],
#  'Intel Core i7 7660U': [None, '2.5GHz'],
#  'Intel Core M m3-7Y30': [None, '2.2GHz'],
#  'Intel Core i5 7Y57': [None, '1.2GHz'],
#  'Intel Core i7 6700HQ': [None, '2.6GHz'],
#  'Intel Core i3 6100U': [None, '2.3GHz'],
#  'AMD A10-Series 9620P': [None, '2.5GHz'],
#  'AMD E-Series 7110': [None, '1.8GHz'],
#  'AMD A9-Series A9-9420': [None, '3GHz'],
#  'Intel Core i7 6820HK': [None, '2.7GHz'],
#  'Intel Core M 7Y30': [None, '1.0GHz'],
#  'Intel Xeon E3-1535M v6': [None, '3.1GHz'],
#  'Intel Celeron Quad Core N3160': [None, '1.6GHz'],
#  'Intel Core i5 6300U': [None, '2.4GHz'],
#  'AMD E-Series E2-9000': [None, '2.2GHz'],
#  'Intel Celeron Dual Core N3050': [None, '1.6GHz'],
#  'Intel Core M M3-6Y30': [None, '0.9GHz'],
#  'Intel Core i5 6300HQ': [None, '2.3GHz'],
#  'AMD A6-Series 7310': [None, '2GHz'],
#  'Intel Atom Z8350': [None, '1.92GHz'],
#  'Intel Xeon E3-1535M v5': [None, '2.9GHz'],
#  'Intel Core i5 6260U': [None, '1.8GHz'],
#  'Intel Pentium Dual Core N4200': [None, '1.1GHz'],
#  'Intel Celeron Quad Core N3710': [None, '1.6GHz'],
#  'AMD A12-Series 9700P': [None, '2.5GHz'],
#  'Intel Pentium Dual Core 4405U': [None, '2.1GHz'],
#  'AMD A4-Series 7210': [None, '2.2GHz'],
#  'Intel Core i7 6560U': [None, '2.2GHz'],
#  'Intel Core M m7-6Y75': [None, '1.2GHz'],
#  'AMD FX 8800P': [None, '2.1GHz'],
#  'Intel Core M M7-6Y75': [None, '1.2GHz'],
#  'Intel Atom X5-Z8350': [None, '1.44GHz'],
#  'Intel Pentium Dual Core 4405Y': [None, '1.5GHz'],
#  'Intel Pentium Quad Core N3700': [None, '1.6GHz'],
#  'Intel Core M 6Y54': [None, '1.1GHz'],
#  'Samsung Cortex A72&A53': [None, '2.0GHz'],
#  'AMD E-Series 9000': [None, '2.2GHz'],
#  'Intel Core M 6Y30': [None, '0.9GHz'],
#  'AMD A9-Series 9410': [None, '2.9GHz']}
