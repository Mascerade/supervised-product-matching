# %%
import pandas as pd
import os
import numpy as np
import random
from tqdm import tqdm
from src.preprocessing import remove_stop_words
from src.common import create_final_data, Common

# %%
class LaptopAttributes():
    '''
    Different from LaptopAttributes, this is specific for creating spec data.
    The spec data was gathered from PCPartPicker and is used to create more laptop data.
    '''

    video_card = {'GeForce RTX 2070'}
    ram = [str(x) + ' GB' for x in range(2, 130, 2)]
    hard_drive = [str(x) + ' GB' for x in range(120, 513, 8)] + [str(x) + ' TB' for x in range(1, 8)]
    cpu = {}
    laptop_brands = ['Lenovo ThinkPad', 'Lenovo ThinkBook', 'Lenovo IdeaPad', 'Lenovo Yoga', 'Lenovo Legion', 'HP Envy', 'HP Chromebook', 'HP Spectre', 'HP ZBook', 'HP Probook', 'HP Elitebook', 'HP Pavilion', 'HP Omen', 'Dell Alienware', 'Dell Vostro', 'Dell Inspiron', 'Dell Latitude', 'Dell XPS', 'Dell G Series', 'Dell Precision', 'Apple Macbook', 'Apple Macbook Air', 'Apple Mac', 'Acer Aspire', 'Acer Swift', 'Acer Spin', 'Acer Switch', 'Acer Extensa', 'Acer Travelmate', 'Acer Nitro', 'Acer Enduro', 'Acer Predator', 'Asus ZenBook', 'Asus Vivobook', 'Asus Republic of Gamers', 'Asus ROG', 'Asus TUF GAMING']
    screen = {'1440x900'}
    inches = {'13.3'}
    
    @staticmethod
    def get_all_data():
        return {
            'cpu': LaptopAttributes.cpu.keys(),
            'ram': LaptopAttributes.ram,
            'hard_drive': LaptopAttributes.hard_drive,
            'video_card': LaptopAttributes.video_card,
            'brand': LaptopAttributes.laptop_brands,
            'screen': LaptopAttributes.screen,
            'inches': LaptopAttributes.inches
        }

# %%
def populate_spec():
    '''
    Creates a string out of the row of product attributes (so row is a Pandas DataFrame).
    '''

    # Getting the CPU data into LaptopAttrbutes
    cpu_df = pd.read_csv('data/train/cpu_data.csv')
    temp_iloc = cpu_df.iloc()
    for idx in range(len(cpu_df)):
        row = temp_iloc[idx]
        LaptopAttributes.cpu[row['name']] = [row['cores'], row['core_clock']]

    # Getting the video card data into LaptopAttributes
    video_card_df = pd.read_csv('data/train/video-cards-data.csv')
    temp_iloc = video_card_df.iloc()
    for idx in range(len(video_card_df)):
        row = temp_iloc[idx]
        LaptopAttributes.video_card.update([row['chipset']])
    
    # Getting the inches, screen, video card, and CPU data from laptops.csv
    laptops_df = pd.read_csv('data/train/laptops.csv', encoding='latin-1')
    LaptopAttributes.inches.update([str(row.Inches) for row in laptops_df[['Inches']].itertuples()])
    LaptopAttributes.screen.update([row.ScreenResolution for row in laptops_df[['ScreenResolution']].itertuples()])
    LaptopAttributes.video_card.update([row.Gpu for row in laptops_df[['Gpu']].itertuples()]) 
    
    for row in laptops_df.iloc:
        if row.Company != 'Apple':
            LaptopAttributes.cpu[' '.join(row.Cpu.split(' ')[:-1])] = [None, row.Cpu.split(' ')[-1]]

# %%
populate_spec()

# %%
def gen_spec_combos():
    '''
    Generates combinations of the spec data (WARNING: THIS TAKES A VERY LONG TIME AND YOU MUST HAVE AT LEAST 16GB RAM TO DO THIS)
    '''

    combos = np.meshgrid(*[list(LaptopAttributes.cpu.keys()), LaptopAttributes.hard_drive, LaptopAttributes.ram])
    combos = np.array(combos).T.reshape(-1, 3)
    np.random.shuffle(combos)
    df = pd.DataFrame(data=combos, columns=['cpu', 'hard_drive', 'ram'])
    df.to_csv('data/train/spec_data_no_brand.csv')

# %%
gen_spec_combos()

# %%
def concatenate_row(row):
    '''
    Creates a string out of the row of product attributes (so row is a Pandas DataFrame)
    '''
    
    # Split the brand
    row['company'] = row['brand'].split(' ')[0]
    row['product'] = ' '.join(row['brand'].split(' ')[1:])
    
    # Create dictionary for drive types
    drive_options = {'ssd': Common.SSD_TYPES, 'hdd': Common.HARD_DRIVE_TYPES}

    # Special tags at the end of the amount of inches of the laptop and the RAM to simulate real data
    inch_attr = str(row['inches']) + random.choice([' inch', '"'])
    ram_attr = row['ram'] + random.choice([' ram', ' memory'])

    # This modifies the CPU attribute to sometimes have different types of elements to add some difference
    # Ex: Intel Core i7 7700k vs Core i7 7700k 4 Core 4.2 GHz CPU (Something like that)
    cpu_attr = row['cpu']
    cores = LaptopAttributes.cpu[cpu_attr][0]
    ghz = LaptopAttributes.cpu[cpu_attr][1]
    
    if random.random() > 0.5:
        cpu_attr = cpu_attr.split(' ')
        if random.choice([0, 1]):
            if 'Intel' in cpu_attr:
                cpu_attr.remove('Intel')
        if random.choice([0, 1]):
            if 'Core' in cpu_attr:
                cpu_attr.remove('Core')
        if random.choice([0, 1]):
            if 'AMD' in cpu_attr:
                cpu_attr.remove('AMD')
    
        cpu_attr = ' '.join(cpu_attr)
    
    # Random chance of putting the cores in the CPU attribute
    if cores != None:
        if random.random() > 0.7:
            cpu_attr = '{} {} {}'.format(cpu_attr, cores, 'Core')
    
    # Random chance of putting the GHz in the CPU attribute
    if random.random() > 0.7:
        cpu_attr = '{} {}'.format(cpu_attr, ghz)
    
    if random.random() > 0.55:
        cpu_attr = '{} {}'.format(cpu_attr, 'CPU')
    
    # Have random chance of getting rid of company or product attribute
    product_removed = False
    if (random.random() > 0.55):
        row['product'] = ''
        product_removed = True
    
    if (random.random() > 0.65 and not product_removed):
        row['company'] = ''
    
    
    # Create a list for all the product attributes
    order_attrs = [row['company'],
                   row['product'],
                   inch_attr,
                  ]

    # Have a chance of adding "laptop" to the title
    if random.random() > 0.45:
        order_attrs.append('laptop')
    
    # Add the type of drive the hard drive attribute
    row['hard_drive'] = row['hard_drive'] + ' ' + random.choice(drive_options[row['drive_type']])
    
    spec_attrs = [row['hard_drive'],
                  # row['screen'],
                   cpu_attr,
                   ram_attr
                 ]
    
    # Shuffle only the attributte
    random.shuffle(spec_attrs)
    order_attrs = order_attrs + spec_attrs
    
    return ' '.join(order_attrs)

# %%
def create_laptop_data(df, neg_attrs):
    temp = []
    for idx in tqdm(range(0, int(len(df) * 0.001))):
        # Must start off with two positive titles
        first_row = df.iloc[idx]
        neg_attr = neg_attrs[idx % len(neg_attrs)]
        
        # Randomly choose the attributes that are not already in the row
        brand = random.choice(LaptopAttributes.laptop_brands)
        inches = random.choice(list(LaptopAttributes.inches))
        screen = random.choice(list(LaptopAttributes.screen))
        hard_drive = random.choice(list(LaptopAttributes.hard_drive))
        drive_type = random.choice(['ssd', 'hdd'])
        
        pos = format_laptop_row(first_row.copy(), brand, inches, screen, drive_type)
        
        new_attr = pos[neg_attr]
        
        while new_attr == pos[neg_attr]:
            new_attr = random.sample(LaptopAttributes.get_all_data()[neg_attr.lower()], 1)[0]
        
        neg = pos.copy()
        neg[neg_attr] = new_attr
        
        pos_pair_1 = remove_stop_words(concatenate_row(pos.copy()))
        pos_pair_2 = remove_stop_words(concatenate_row(pos.copy()))
        neg_pair_1 = remove_stop_words(concatenate_row(neg.copy()))
        neg_pair_2 = remove_stop_words(concatenate_row(neg.copy()))
        
        temp.append([pos_pair_1, pos_pair_2, 1])
        temp.append([neg_pair_1, neg_pair_2, 1])
        temp.append([pos_pair_1, neg_pair_1, 0])
        temp.append([pos_pair_2, neg_pair_2, 0])
    
    return pd.DataFrame(temp, columns=Common.COLUMN_NAMES)

# %%
def format_laptop_row(row, brand, inches, screen, drive_type):
    row['brand'] = brand
    row['inches'] = inches
    row['screen'] = screen
    row['drive_type'] = drive_type
    return row

# %%
spec_data = pd.read_csv('data/train/spec_data_no_brand.csv')

# %%
new_data = create_laptop_data(spec_data, neg_attrs=['brand', 'cpu', 'ram', 'inches', 'hard_drive'])
# Out:
# 100%|█████████████████████████████████████████████████████████████| 678/678 [00:06<00:00, 107.87it/s]

# %%
for row in new_data.iloc:
    print('1. ', row.title_one)
    print('2. ', row.title_two)
    print('Label: ', row.label)
    print('----------------------------------------------------')
# Out:
# 1.  Acer Extensa 14 1 inch laptop Core i7 9700K 8 Core 3 6 GHz CPU 34 GB ram 392 GB Hard Drive
# 2.  Extensa 14 1 inch 392 GB Hard Drive 34 GB ram Intel Core i7 9700K
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 14 1 inch laptop 34 GB ram Intel Core i7 9700K 392 GB Hard Drive
# 2.  Lenovo IdeaPad 14 1" 392 GB HDD 34 GB ram Core i7 9700K
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 14 1 inch laptop Core i7 9700K 8 Core 3 6 GHz CPU 34 GB ram 392 GB Hard Drive
# 2.  Lenovo 14 1 inch laptop 34 GB ram Intel Core i7 9700K 392 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Extensa 14 1 inch 392 GB Hard Drive 34 GB ram Intel Core i7 9700K
# 2.  Lenovo IdeaPad 14 1" 392 GB HDD 34 GB ram Core i7 9700K
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo Yoga 13 9" 108 GB ram 304 GB SSD Intel Celeron Dual Core 3205U
# 2.  Lenovo 13 9" Intel Celeron Dual Core 3205U CPU 108 GB ram 304 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo Yoga 13 9" Intel Pentium Quad Core N3700 304 GB SSD 108 GB memory
# 2.  Yoga 13 9" laptop Pentium Quad N3700 1 6GHz CPU 108 GB ram 304 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo Yoga 13 9" 108 GB ram 304 GB SSD Intel Celeron Dual Core 3205U
# 2.  Lenovo Yoga 13 9" Intel Pentium Quad Core N3700 304 GB SSD 108 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 13 9" Intel Celeron Dual Core 3205U CPU 108 GB ram 304 GB M 2 SSD
# 2.  Yoga 13 9" laptop Pentium Quad N3700 1 6GHz CPU 108 GB ram 304 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Extensa 11 3" laptop 120 GB SSD Intel Core i5 4460 CPU 118 GB ram
# 2.  Acer 11 3 inch i5 4460 120 GB M 2 SSD 118 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Extensa 11 3" 18 GB memory Core i5 4460 3 2 GHz 120 GB SSD
# 2.  Extensa 11 3" 120 GB SSD 18 GB ram Core i5 4460 4 Core CPU
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 11 3" laptop 120 GB SSD Intel Core i5 4460 CPU 118 GB ram
# 2.  Extensa 11 3" 18 GB memory Core i5 4460 3 2 GHz 120 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 11 3 inch i5 4460 120 GB M 2 SSD 118 GB memory
# 2.  Extensa 11 3" 120 GB SSD 18 GB ram Core i5 4460 4 Core CPU
# Label:  0
# ----------------------------------------------------
# 1.  Asus ZenBook 12 5 inch laptop 96 GB memory Core i7 7560U CPU 224 GB Hard Drive
# 2.  Asus 12 5 inch laptop Core i7 7560U 224 GB HDD 96 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Asus ZenBook 13 5 inch 224 GB Hard Drive Intel Core i7 7560U CPU 96 GB memory
# 2.  Asus ZenBook 13 5 inch laptop 224 GB Internal Hard Drive 96 GB ram Intel Core i7 7560U
# Label:  1
# ----------------------------------------------------
# 1.  Asus ZenBook 12 5 inch laptop 96 GB memory Core i7 7560U CPU 224 GB Hard Drive
# 2.  Asus ZenBook 13 5 inch 224 GB Hard Drive Intel Core i7 7560U CPU 96 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Asus 12 5 inch laptop Core i7 7560U 224 GB HDD 96 GB ram
# 2.  Asus ZenBook 13 5 inch laptop 224 GB Internal Hard Drive 96 GB ram Intel Core i7 7560U
# Label:  0
# ----------------------------------------------------
# 1.  Dell Latitude 12 0" laptop Core i5 2400 4 Core 304 GB Hard Drive 92 GB ram
# 2.  Dell Latitude 12 0" laptop 304 GB Internal Hard Drive i5 2400 CPU 92 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Latitude 12 0 inch laptop 92 GB memory 336 GB Hard Drive Intel Core i5 2400
# 2.  Dell 12 0 inch Intel Core i5 2400 3 1 GHz CPU 336 GB Hard Drive 92 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Dell Latitude 12 0" laptop Core i5 2400 4 Core 304 GB Hard Drive 92 GB ram
# 2.  Latitude 12 0 inch laptop 92 GB memory 336 GB Hard Drive Intel Core i5 2400
# Label:  0
# ----------------------------------------------------
# 1.  Dell Latitude 12 0" laptop 304 GB Internal Hard Drive i5 2400 CPU 92 GB memory
# 2.  Dell 12 0 inch Intel Core i5 2400 3 1 GHz CPU 336 GB Hard Drive 92 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Dell 15 6 inch 120 GB memory 304 GB Hard Drive AMD Ryzen 5 1600 12nm 6 Core 3 2 GHz CPU
# 2.  Dell G Series 15 6" laptop AMD Ryzen 5 1600 12nm 3 2 GHz CPU 304 GB HDD 120 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  HP Envy 15 6" 304 GB Internal Hard Drive AMD Ryzen 5 1600 12nm 6 Core 120 GB ram
# 2.  HP Envy 15 6 inch laptop AMD Ryzen 5 1600 12nm CPU 304 GB Hard Drive 120 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Dell 15 6 inch 120 GB memory 304 GB Hard Drive AMD Ryzen 5 1600 12nm 6 Core 3 2 GHz CPU
# 2.  HP Envy 15 6" 304 GB Internal Hard Drive AMD Ryzen 5 1600 12nm 6 Core 120 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell G Series 15 6" laptop AMD Ryzen 5 1600 12nm 3 2 GHz CPU 304 GB HDD 120 GB memory
# 2.  HP Envy 15 6 inch laptop AMD Ryzen 5 1600 12nm CPU 304 GB Hard Drive 120 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Apple 13 9" laptop Intel Core i7 6700 92 GB ram 328 GB SATA SSD
# 2.  Apple Mac 13 9 inch Core i7 6700 CPU 92 GB ram 328 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Mac 13 9 inch laptop 92 GB ram Intel Core i7 7700K CPU 328 GB M 2 SSD
# 2.  Apple Mac 13 9" laptop Intel Core i7 7700K 92 GB ram 328 GB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  Apple 13 9" laptop Intel Core i7 6700 92 GB ram 328 GB SATA SSD
# 2.  Mac 13 9 inch laptop 92 GB ram Intel Core i7 7700K CPU 328 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Apple Mac 13 9 inch Core i7 6700 CPU 92 GB ram 328 GB M 2 SSD
# 2.  Apple Mac 13 9" laptop Intel Core i7 7700K 92 GB ram 328 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Asus TUF GAMING 13 0 inch laptop 10 GB ram 288 GB Internal Hard Drive AMD Ryzen 3 1200 12nm CPU
# 2.  Asus 13 0" Ryzen 3 1200 12nm CPU 288 GB HDD 10 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Asus 13 0 inch laptop 124 GB ram Ryzen 3 1200 12nm 288 GB Internal Hard Drive
# 2.  Asus 13 0" laptop Ryzen 3 1200 12nm CPU 288 GB Hard Drive 124 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Asus TUF GAMING 13 0 inch laptop 10 GB ram 288 GB Internal Hard Drive AMD Ryzen 3 1200 12nm CPU
# 2.  Asus 13 0 inch laptop 124 GB ram Ryzen 3 1200 12nm 288 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Asus 13 0" Ryzen 3 1200 12nm CPU 288 GB HDD 10 GB memory
# 2.  Asus 13 0" laptop Ryzen 3 1200 12nm CPU 288 GB Hard Drive 124 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Macbook 11 6 inch laptop Celeron Dual Core N3050 128 GB Hard Drive 124 GB memory
# 2.  Apple 11 6" Celeron Dual N3050 1 6GHz 124 GB ram 128 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Macbook 11 3 inch 124 GB memory Intel Celeron Dual Core N3050 128 GB Hard Drive
# 2.  Apple Macbook 11 3 inch laptop 128 GB Hard Drive Celeron Dual N3050 124 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Macbook 11 6 inch laptop Celeron Dual Core N3050 128 GB Hard Drive 124 GB memory
# 2.  Macbook 11 3 inch 124 GB memory Intel Celeron Dual Core N3050 128 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Apple 11 6" Celeron Dual N3050 1 6GHz 124 GB ram 128 GB Internal Hard Drive
# 2.  Apple Macbook 11 3 inch laptop 128 GB Hard Drive Celeron Dual N3050 124 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP ZBook 12 5 inch laptop 288 GB HDD 70 GB memory AMD Ryzen 5 3600X CPU
# 2.  HP ZBook 12 5" AMD Ryzen 5 3600X 6 Core 70 GB memory 288 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 12 5 inch AMD Ryzen 5 3600X 70 GB ram 184 GB Hard Drive
# 2.  ZBook 12 5 inch laptop 184 GB HDD AMD Ryzen 5 3600X 70 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  HP ZBook 12 5 inch laptop 288 GB HDD 70 GB memory AMD Ryzen 5 3600X CPU
# 2.  HP 12 5 inch AMD Ryzen 5 3600X 70 GB ram 184 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP ZBook 12 5" AMD Ryzen 5 3600X 6 Core 70 GB memory 288 GB Internal Hard Drive
# 2.  ZBook 12 5 inch laptop 184 GB HDD AMD Ryzen 5 3600X 70 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 5 inch Intel Xeon E3 1505M V6 3GHz 456 GB Hard Drive 32 GB memory
# 2.  Acer 13 5" laptop Intel Xeon E3 1505M V6 456 GB Hard Drive 32 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Predator 13 5 inch laptop 32 GB ram Intel Xeon E3 1505M V6 456 GB Internal Hard Drive
# 2.  Predator 13 5 inch 32 GB ram Intel Xeon E3 1505M V6 456 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 5 inch Intel Xeon E3 1505M V6 3GHz 456 GB Hard Drive 32 GB memory
# 2.  Predator 13 5 inch laptop 32 GB ram Intel Xeon E3 1505M V6 456 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 5" laptop Intel Xeon E3 1505M V6 456 GB Hard Drive 32 GB memory
# 2.  Predator 13 5 inch 32 GB ram Intel Xeon E3 1505M V6 456 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Asus 12 5 inch 488 GB HDD 46 GB ram i3 7130U CPU
# 2.  Asus 12 5 inch 46 GB ram Intel Core i3 7130U CPU 488 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Asus 12 5 inch laptop 488 GB HDD E Series 7110 1 8GHz 46 GB ram
# 2.  ZenBook 12 5" laptop 488 GB HDD 46 GB memory AMD E Series 7110
# Label:  1
# ----------------------------------------------------
# 1.  Asus 12 5 inch 488 GB HDD 46 GB ram i3 7130U CPU
# 2.  Asus 12 5 inch laptop 488 GB HDD E Series 7110 1 8GHz 46 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Asus 12 5 inch 46 GB ram Intel Core i3 7130U CPU 488 GB Hard Drive
# 2.  ZenBook 12 5" laptop 488 GB HDD 46 GB memory AMD E Series 7110
# Label:  0
# ----------------------------------------------------
# 1.  Dell Precision 13 0" 152 GB HDD 116 GB ram Intel Core i7 7600U 2 8GHz
# 2.  Precision 13 0" Intel i7 7600U 2 8GHz 116 GB memory 152 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Precision 13 0 inch laptop Intel i7 7600U CPU 152 GB HDD 124 GB memory
# 2.  Precision 13 0" laptop 124 GB memory 152 GB HDD i7 7600U 2 8GHz CPU
# Label:  1
# ----------------------------------------------------
# 1.  Dell Precision 13 0" 152 GB HDD 116 GB ram Intel Core i7 7600U 2 8GHz
# 2.  Precision 13 0 inch laptop Intel i7 7600U CPU 152 GB HDD 124 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Precision 13 0" Intel i7 7600U 2 8GHz 116 GB memory 152 GB HDD
# 2.  Precision 13 0" laptop 124 GB memory 152 GB HDD i7 7600U 2 8GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Dell Latitude 10 1" laptop 22 GB memory Intel Core i7 9700KF 8 Core 392 GB SATA SSD
# 2.  Latitude 10 1" laptop Intel Core i7 9700KF 22 GB memory 392 GB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  Latitude 18 4" laptop 22 GB ram 392 GB M 2 SSD Intel Core i7 9700KF
# 2.  Dell 18 4 inch laptop 392 GB SSD Intel Core i7 9700KF 3 6 GHz 22 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Dell Latitude 10 1" laptop 22 GB memory Intel Core i7 9700KF 8 Core 392 GB SATA SSD
# 2.  Latitude 18 4" laptop 22 GB ram 392 GB M 2 SSD Intel Core i7 9700KF
# Label:  0
# ----------------------------------------------------
# 1.  Latitude 10 1" laptop Intel Core i7 9700KF 22 GB memory 392 GB Solid State Drive
# 2.  Dell 18 4 inch laptop 392 GB SSD Intel Core i7 9700KF 3 6 GHz 22 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo ThinkPad 13 0 inch laptop Intel Core i7 7700HQ CPU 136 GB Hard Drive 72 GB ram
# 2.  ThinkPad 13 0" Intel Core i7 7700HQ CPU 136 GB Hard Drive 72 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 13 0" 352 GB Hard Drive Intel Core i7 7700HQ CPU 72 GB ram
# 2.  ThinkPad 13 0" Core i7 7700HQ 72 GB ram 352 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo ThinkPad 13 0 inch laptop Intel Core i7 7700HQ CPU 136 GB Hard Drive 72 GB ram
# 2.  Lenovo 13 0" 352 GB Hard Drive Intel Core i7 7700HQ CPU 72 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  ThinkPad 13 0" Intel Core i7 7700HQ CPU 136 GB Hard Drive 72 GB memory
# 2.  ThinkPad 13 0" Core i7 7700HQ 72 GB ram 352 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 15 6" 12 GB memory 408 GB SATA SSD Intel Core M M3 6Y30 CPU
# 2.  Acer Extensa 15 6" laptop 12 GB memory 408 GB M 2 SSD Intel Core M M3 6Y30
# Label:  1
# ----------------------------------------------------
# 1.  Acer Predator 15 6" laptop Intel Core M M3 6Y30 12 GB memory 408 GB SATA SSD
# 2.  Acer 15 6 inch 408 GB SATA SSD 12 GB ram Intel Core M M3 6Y30
# Label:  1
# ----------------------------------------------------
# 1.  Acer 15 6" 12 GB memory 408 GB SATA SSD Intel Core M M3 6Y30 CPU
# 2.  Acer Predator 15 6" laptop Intel Core M M3 6Y30 12 GB memory 408 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Extensa 15 6" laptop 12 GB memory 408 GB M 2 SSD Intel Core M M3 6Y30
# 2.  Acer 15 6 inch 408 GB SATA SSD 12 GB ram Intel Core M M3 6Y30
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo Yoga 15 6 inch laptop Intel Core i5 4460 3 2 GHz 152 GB M 2 SSD 32 GB memory
# 2.  Yoga 15 6" laptop 152 GB M 2 SSD Intel Core i5 4460 4 Core CPU 32 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 15 6 inch laptop Intel Xeon E3 1535M v6 3 1GHz CPU 32 GB ram 152 GB SATA SSD
# 2.  Lenovo 15 6 inch laptop 32 GB memory Intel Xeon E3 1535M v6 3 1GHz 152 GB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo Yoga 15 6 inch laptop Intel Core i5 4460 3 2 GHz 152 GB M 2 SSD 32 GB memory
# 2.  Lenovo 15 6 inch laptop Intel Xeon E3 1535M v6 3 1GHz CPU 32 GB ram 152 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Yoga 15 6" laptop 152 GB M 2 SSD Intel Core i5 4460 4 Core CPU 32 GB ram
# 2.  Lenovo 15 6 inch laptop 32 GB memory Intel Xeon E3 1535M v6 3 1GHz 152 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP Elitebook 13 5 inch laptop 3 TB Internal Hard Drive 48 GB ram Intel Core i7 6700K 4 GHz CPU
# 2.  HP 13 5" Intel Core i7 6700K CPU 48 GB memory 3 TB HDD
# Label:  1
# ----------------------------------------------------
# 1.  HP Elitebook 13 5 inch laptop 56 GB ram Intel Core i7 6700K 4 Core 3 TB Internal Hard Drive
# 2.  Elitebook 13 5" Core i7 6700K 4 GHz 3 TB HDD 56 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  HP Elitebook 13 5 inch laptop 3 TB Internal Hard Drive 48 GB ram Intel Core i7 6700K 4 GHz CPU
# 2.  HP Elitebook 13 5 inch laptop 56 GB ram Intel Core i7 6700K 4 Core 3 TB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP 13 5" Intel Core i7 6700K CPU 48 GB memory 3 TB HDD
# 2.  Elitebook 13 5" Core i7 6700K 4 GHz 3 TB HDD 56 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Switch 13 5" laptop 200 GB HDD 12 GB memory Core i5 7300U 2 6GHz
# 2.  Acer 13 5 inch laptop 12 GB memory i5 7300U 2 6GHz 200 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 9" 12 GB memory Intel Core i5 7300U CPU 200 GB Hard Drive
# 2.  Acer 13 9 inch laptop i5 7300U CPU 200 GB Hard Drive 12 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Switch 13 5" laptop 200 GB HDD 12 GB memory Core i5 7300U 2 6GHz
# 2.  Acer 13 9" 12 GB memory Intel Core i5 7300U CPU 200 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 5 inch laptop 12 GB memory i5 7300U 2 6GHz 200 GB HDD
# 2.  Acer 13 9 inch laptop i5 7300U CPU 200 GB Hard Drive 12 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  HP 17 0 inch 472 GB SATA SSD 112 GB memory Intel Core i5 4590 CPU
# 2.  HP 17 0 inch laptop 112 GB memory Intel Core i5 4590 472 GB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 17 0 inch laptop 112 GB ram 240 GB SATA SSD Intel Core i5 4590
# 2.  HP 17 0" laptop 112 GB memory Core i5 4590 240 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  HP 17 0 inch 472 GB SATA SSD 112 GB memory Intel Core i5 4590 CPU
# 2.  HP 17 0 inch laptop 112 GB ram 240 GB SATA SSD Intel Core i5 4590
# Label:  0
# ----------------------------------------------------
# 1.  HP 17 0 inch laptop 112 GB memory Intel Core i5 4590 472 GB Solid State Drive
# 2.  HP 17 0" laptop 112 GB memory Core i5 4590 240 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Asus ZenBook 13 3 inch laptop Intel Xeon E5 2690 V4 416 GB Internal Hard Drive 20 GB ram
# 2.  Asus ZenBook 13 3" 416 GB Hard Drive 20 GB ram Intel Xeon E5 2690 V4 14 Core CPU
# Label:  1
# ----------------------------------------------------
# 1.  Spectre 13 3" Intel Xeon E5 2690 V4 CPU 20 GB memory 416 GB Internal Hard Drive
# 2.  Spectre 13 3 inch 20 GB memory Intel Xeon E5 2690 V4 2 6 GHz CPU 416 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Asus ZenBook 13 3 inch laptop Intel Xeon E5 2690 V4 416 GB Internal Hard Drive 20 GB ram
# 2.  Spectre 13 3" Intel Xeon E5 2690 V4 CPU 20 GB memory 416 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Asus ZenBook 13 3" 416 GB Hard Drive 20 GB ram Intel Xeon E5 2690 V4 14 Core CPU
# 2.  Spectre 13 3 inch 20 GB memory Intel Xeon E5 2690 V4 2 6 GHz CPU 416 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Extensa 12 3" 8 GB ram Core i7 7700HQ 2 8GHz 480 GB SSD
# 2.  Acer 12 3" 8 GB ram Intel Core i7 7700HQ CPU 480 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 12 3 inch laptop 8 GB memory i5 7500U CPU 480 GB SATA SSD
# 2.  Acer Extensa 12 3 inch 480 GB Solid State Drive Intel Core i5 7500U 2 7GHz CPU 8 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 12 3" 8 GB ram Core i7 7700HQ 2 8GHz 480 GB SSD
# 2.  Acer Extensa 12 3 inch laptop 8 GB memory i5 7500U CPU 480 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 12 3" 8 GB ram Intel Core i7 7700HQ CPU 480 GB SATA SSD
# 2.  Acer Extensa 12 3 inch 480 GB Solid State Drive Intel Core i5 7500U 2 7GHz CPU 8 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  IdeaPad 13 9 inch laptop 224 GB SSD 42 GB ram Ryzen 7 1700 3 GHz
# 2.  Lenovo IdeaPad 13 9" 224 GB SSD 42 GB memory AMD Ryzen 7 1700
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 13 9 inch laptop AMD Ryzen 7 1700 8 Core CPU 88 GB ram 224 GB M 2 SSD
# 2.  Lenovo IdeaPad 13 9 inch Ryzen 7 1700 8 Core CPU 224 GB SATA SSD 88 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  IdeaPad 13 9 inch laptop 224 GB SSD 42 GB ram Ryzen 7 1700 3 GHz
# 2.  Lenovo 13 9 inch laptop AMD Ryzen 7 1700 8 Core CPU 88 GB ram 224 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo IdeaPad 13 9" 224 GB SSD 42 GB memory AMD Ryzen 7 1700
# 2.  Lenovo IdeaPad 13 9 inch Ryzen 7 1700 8 Core CPU 224 GB SATA SSD 88 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Asus ROG 11 6 inch Intel Core i7 7500U 2 7GHz CPU 384 GB SATA SSD 118 GB memory
# 2.  Asus 11 6" laptop 384 GB SATA SSD Intel Core i7 7500U 118 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Asus 13 3 inch laptop i7 7500U CPU 118 GB memory 384 GB SSD
# 2.  ROG 13 3" laptop 118 GB memory 384 GB SSD i7 7500U
# Label:  1
# ----------------------------------------------------
# 1.  Asus ROG 11 6 inch Intel Core i7 7500U 2 7GHz CPU 384 GB SATA SSD 118 GB memory
# 2.  Asus 13 3 inch laptop i7 7500U CPU 118 GB memory 384 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Asus 11 6" laptop 384 GB SATA SSD Intel Core i7 7500U 118 GB memory
# 2.  ROG 13 3" laptop 118 GB memory 384 GB SSD i7 7500U
# Label:  0
# ----------------------------------------------------
# 1.  Dell XPS 14 1 inch laptop 74 GB memory 120 GB SSD i3 6006U 2GHz CPU
# 2.  Dell 14 1" 120 GB Solid State Drive 74 GB ram Intel i3 6006U 2GHz
# Label:  1
# ----------------------------------------------------
# 1.  XPS 14 1" laptop Intel Core i3 6006U CPU 74 GB ram 512 GB SSD
# 2.  Dell XPS 14 1" laptop Intel Core i3 6006U 2GHz 74 GB ram 512 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell XPS 14 1 inch laptop 74 GB memory 120 GB SSD i3 6006U 2GHz CPU
# 2.  XPS 14 1" laptop Intel Core i3 6006U CPU 74 GB ram 512 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Dell 14 1" 120 GB Solid State Drive 74 GB ram Intel i3 6006U 2GHz
# 2.  Dell XPS 14 1" laptop Intel Core i3 6006U 2GHz 74 GB ram 512 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Dell Precision 12 5" 16 GB ram 400 GB HDD Intel Core i5 6440HQ 2 6GHz
# 2.  Dell 12 5" laptop 16 GB memory Intel Core i5 6440HQ CPU 400 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 12 5 inch laptop Intel Core i5 6440HQ 2 6GHz 16 GB memory 400 GB Hard Drive
# 2.  Pavilion 12 5 inch laptop 16 GB memory Intel i5 6440HQ 400 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Dell Precision 12 5" 16 GB ram 400 GB HDD Intel Core i5 6440HQ 2 6GHz
# 2.  HP 12 5 inch laptop Intel Core i5 6440HQ 2 6GHz 16 GB memory 400 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Dell 12 5" laptop 16 GB memory Intel Core i5 6440HQ CPU 400 GB Hard Drive
# 2.  Pavilion 12 5 inch laptop 16 GB memory Intel i5 6440HQ 400 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 0" laptop 288 GB M 2 SSD 122 GB memory Intel Core 2 Duo E7300 CPU
# 2.  Acer 13 0" 288 GB SATA SSD 2 Duo E7300 CPU 122 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 0 inch AMD Ryzen 5 1600 12nm CPU 122 GB memory 288 GB SATA SSD
# 2.  Acer 13 0" laptop 122 GB memory AMD Ryzen 5 1600 12nm 288 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 0" laptop 288 GB M 2 SSD 122 GB memory Intel Core 2 Duo E7300 CPU
# 2.  Acer 13 0 inch AMD Ryzen 5 1600 12nm CPU 122 GB memory 288 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 0" 288 GB SATA SSD 2 Duo E7300 CPU 122 GB ram
# 2.  Acer 13 0" laptop 122 GB memory AMD Ryzen 5 1600 12nm 288 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Apple Mac 14 0" AMD FX 8350 4 GHz 16 GB ram 1 TB SATA SSD
# 2.  Apple 14 0 inch 1 TB SSD AMD FX 8350 16 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Apple 14 0 inch 18 GB memory AMD FX 8350 8 Core CPU 1 TB SSD
# 2.  Apple 14 0" 1 TB M 2 SSD AMD FX 8350 CPU 18 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Apple Mac 14 0" AMD FX 8350 4 GHz 16 GB ram 1 TB SATA SSD
# 2.  Apple 14 0 inch 18 GB memory AMD FX 8350 8 Core CPU 1 TB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Apple 14 0 inch 1 TB SSD AMD FX 8350 16 GB memory
# 2.  Apple 14 0" 1 TB M 2 SSD AMD FX 8350 CPU 18 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo Legion 12 3" 136 GB Internal Hard Drive A10 Series 9600P 80 GB ram
# 2.  Lenovo 12 3 inch 80 GB ram AMD A10 Series 9600P 2 4GHz CPU 136 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 12 0 inch laptop 136 GB Hard Drive AMD A10 Series 9600P CPU 80 GB ram
# 2.  Lenovo Legion 12 0 inch laptop A10 Series 9600P 2 4GHz 80 GB memory 136 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo Legion 12 3" 136 GB Internal Hard Drive A10 Series 9600P 80 GB ram
# 2.  Lenovo 12 0 inch laptop 136 GB Hard Drive AMD A10 Series 9600P CPU 80 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 12 3 inch 80 GB ram AMD A10 Series 9600P 2 4GHz CPU 136 GB Hard Drive
# 2.  Lenovo Legion 12 0 inch laptop A10 Series 9600P 2 4GHz 80 GB memory 136 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Spectre 13 0" laptop 160 GB M 2 SSD AMD Threadripper 3970X 32 Core CPU 114 GB ram
# 2.  HP 13 0" Threadripper 3970X 160 GB M 2 SSD 114 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  HP Spectre 13 0 inch laptop 114 GB ram AMD Threadripper 3970X 32 Core CPU 192 GB M 2 SSD
# 2.  HP 13 0 inch AMD Threadripper 3970X 3 7 GHz 114 GB ram 192 GB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Spectre 13 0" laptop 160 GB M 2 SSD AMD Threadripper 3970X 32 Core CPU 114 GB ram
# 2.  HP Spectre 13 0 inch laptop 114 GB ram AMD Threadripper 3970X 32 Core CPU 192 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  HP 13 0" Threadripper 3970X 160 GB M 2 SSD 114 GB memory
# 2.  HP 13 0 inch AMD Threadripper 3970X 3 7 GHz 114 GB ram 192 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  HP 12 3" 360 GB HDD 112 GB memory AMD A9 Series 9420 CPU
# 2.  HP 12 3" 112 GB ram AMD A9 Series 9420 360 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Spin 12 3 inch 360 GB Hard Drive AMD A9 Series 9420 CPU 112 GB ram
# 2.  Acer 12 3" laptop 112 GB ram AMD A9 Series 9420 CPU 360 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 12 3" 360 GB HDD 112 GB memory AMD A9 Series 9420 CPU
# 2.  Acer Spin 12 3 inch 360 GB Hard Drive AMD A9 Series 9420 CPU 112 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP 12 3" 112 GB ram AMD A9 Series 9420 360 GB Hard Drive
# 2.  Acer 12 3" laptop 112 GB ram AMD A9 Series 9420 CPU 360 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  IdeaPad 11 3 inch 464 GB Hard Drive Core i5 7400 3 GHz 78 GB memory
# 2.  Lenovo 11 3" laptop 78 GB ram 464 GB Internal Hard Drive Intel Core i5 7400
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 11 3 inch laptop 78 GB memory 464 GB Internal Hard Drive AMD E Series 6110 CPU
# 2.  Lenovo IdeaPad 11 3" laptop 78 GB memory AMD E Series 6110 464 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  IdeaPad 11 3 inch 464 GB Hard Drive Core i5 7400 3 GHz 78 GB memory
# 2.  Lenovo 11 3 inch laptop 78 GB memory 464 GB Internal Hard Drive AMD E Series 6110 CPU
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 11 3" laptop 78 GB ram 464 GB Internal Hard Drive Intel Core i5 7400
# 2.  Lenovo IdeaPad 11 3" laptop 78 GB memory AMD E Series 6110 464 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Asus 12 3 inch i7 7700HQ 100 GB memory 400 GB SATA SSD
# 2.  ROG 12 3" 100 GB ram Core i7 7700HQ CPU 400 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Asus 12 3" 116 GB memory Intel Core i7 7700HQ 2 8GHz CPU 400 GB SSD
# 2.  Asus 12 3 inch 116 GB memory 400 GB Solid State Drive Intel Core i7 7700HQ CPU
# Label:  1
# ----------------------------------------------------
# 1.  Asus 12 3 inch i7 7700HQ 100 GB memory 400 GB SATA SSD
# 2.  Asus 12 3" 116 GB memory Intel Core i7 7700HQ 2 8GHz CPU 400 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  ROG 12 3" 100 GB ram Core i7 7700HQ CPU 400 GB M 2 SSD
# 2.  Asus 12 3 inch 116 GB memory 400 GB Solid State Drive Intel Core i7 7700HQ CPU
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 13 0 inch laptop 114 GB ram Ryzen 3 3200G 4 Core 408 GB Solid State Drive
# 2.  Lenovo 13 0" laptop 408 GB Solid State Drive 114 GB memory AMD Ryzen 3 3200G 3 6 GHz CPU
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 11 6" laptop 114 GB ram 408 GB SSD Ryzen 3 3200G 3 6 GHz CPU
# 2.  Lenovo Legion 11 6 inch 114 GB ram AMD Ryzen 3 3200G 3 6 GHz CPU 408 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 13 0 inch laptop 114 GB ram Ryzen 3 3200G 4 Core 408 GB Solid State Drive
# 2.  Lenovo 11 6" laptop 114 GB ram 408 GB SSD Ryzen 3 3200G 3 6 GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 13 0" laptop 408 GB Solid State Drive 114 GB memory AMD Ryzen 3 3200G 3 6 GHz CPU
# 2.  Lenovo Legion 11 6 inch 114 GB ram AMD Ryzen 3 3200G 3 6 GHz CPU 408 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Spin 13 3" laptop AMD Ryzen 3 3200G CPU 112 GB ram 384 GB Solid State Drive
# 2.  Acer Spin 13 3" laptop 384 GB Solid State Drive AMD Ryzen 3 3200G 3 6 GHz CPU 112 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Acer Spin 13 3" laptop 112 GB memory 224 GB Solid State Drive AMD Ryzen 3 3200G
# 2.  Acer Spin 13 3 inch AMD Ryzen 3 3200G 3 6 GHz 112 GB memory 224 GB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Spin 13 3" laptop AMD Ryzen 3 3200G CPU 112 GB ram 384 GB Solid State Drive
# 2.  Acer Spin 13 3" laptop 112 GB memory 224 GB Solid State Drive AMD Ryzen 3 3200G
# Label:  0
# ----------------------------------------------------
# 1.  Acer Spin 13 3" laptop 384 GB Solid State Drive AMD Ryzen 3 3200G 3 6 GHz CPU 112 GB ram
# 2.  Acer Spin 13 3 inch AMD Ryzen 3 3200G 3 6 GHz 112 GB memory 224 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Spin 13 3" laptop 110 GB memory 144 GB HDD Intel Core i7 6560U CPU
# 2.  Acer 13 3 inch 110 GB memory 144 GB Internal Hard Drive Core i7 6560U
# Label:  1
# ----------------------------------------------------
# 1.  ROG 13 3 inch laptop Intel Core i7 6560U 2 2GHz 144 GB HDD 110 GB memory
# 2.  Asus 13 3" Intel Core i7 6560U 2 2GHz CPU 144 GB HDD 110 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Spin 13 3" laptop 110 GB memory 144 GB HDD Intel Core i7 6560U CPU
# 2.  ROG 13 3 inch laptop Intel Core i7 6560U 2 2GHz 144 GB HDD 110 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 3 inch 110 GB memory 144 GB Internal Hard Drive Core i7 6560U
# 2.  Asus 13 3" Intel Core i7 6560U 2 2GHz CPU 144 GB HDD 110 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Dell 15 4 inch laptop 24 GB ram 176 GB SATA SSD Intel i5 7600K 4 Core
# 2.  G Series 15 4" 176 GB SATA SSD 24 GB memory Intel i5 7600K 3 8 GHz
# Label:  1
# ----------------------------------------------------
# 1.  Dell G Series 15 4 inch laptop 176 GB Solid State Drive 24 GB ram Intel Core i9 9900K CPU
# 2.  Dell 15 4" laptop 176 GB Solid State Drive Intel Core i9 9900K CPU 24 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Dell 15 4 inch laptop 24 GB ram 176 GB SATA SSD Intel i5 7600K 4 Core
# 2.  Dell G Series 15 4 inch laptop 176 GB Solid State Drive 24 GB ram Intel Core i9 9900K CPU
# Label:  0
# ----------------------------------------------------
# 1.  G Series 15 4" 176 GB SATA SSD 24 GB memory Intel i5 7600K 3 8 GHz
# 2.  Dell 15 4" laptop 176 GB Solid State Drive Intel Core i9 9900K CPU 24 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell 12 5 inch laptop AMD Ryzen 5 3600X 6 Core CPU 280 GB SATA SSD 110 GB memory
# 2.  Alienware 12 5 inch 280 GB SATA SSD AMD Ryzen 5 3600X 110 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Dell Alienware 12 5" 86 GB memory AMD Ryzen 5 3600X 280 GB Solid State Drive
# 2.  Dell Alienware 12 5 inch laptop 86 GB memory AMD Ryzen 5 3600X 3 8 GHz CPU 280 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell 12 5 inch laptop AMD Ryzen 5 3600X 6 Core CPU 280 GB SATA SSD 110 GB memory
# 2.  Dell Alienware 12 5" 86 GB memory AMD Ryzen 5 3600X 280 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Alienware 12 5 inch 280 GB SATA SSD AMD Ryzen 5 3600X 110 GB ram
# 2.  Dell Alienware 12 5 inch laptop 86 GB memory AMD Ryzen 5 3600X 3 8 GHz CPU 280 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  HP Spectre 15 0" laptop 496 GB Solid State Drive 128 GB ram Ryzen 5 1600X 6 Core
# 2.  Spectre 15 0" laptop 496 GB SSD 128 GB ram AMD Ryzen 5 1600X
# Label:  1
# ----------------------------------------------------
# 1.  HP 15 6 inch laptop 128 GB memory 496 GB M 2 SSD Ryzen 5 1600X 3 6 GHz CPU
# 2.  HP Spectre 15 6 inch 128 GB memory 496 GB M 2 SSD AMD Ryzen 5 1600X
# Label:  1
# ----------------------------------------------------
# 1.  HP Spectre 15 0" laptop 496 GB Solid State Drive 128 GB ram Ryzen 5 1600X 6 Core
# 2.  HP 15 6 inch laptop 128 GB memory 496 GB M 2 SSD Ryzen 5 1600X 3 6 GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Spectre 15 0" laptop 496 GB SSD 128 GB ram AMD Ryzen 5 1600X
# 2.  HP Spectre 15 6 inch 128 GB memory 496 GB M 2 SSD AMD Ryzen 5 1600X
# Label:  0
# ----------------------------------------------------
# 1.  Asus 13 0" laptop 18 GB ram 5 TB Hard Drive AMD Ryzen 7 3800X CPU
# 2.  TUF GAMING 13 0 inch 18 GB memory AMD Ryzen 7 3800X 3 9 GHz 5 TB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Asus TUF GAMING 13 0 inch AMD Ryzen 7 3800X CPU 18 GB memory 1 TB Internal Hard Drive
# 2.  Asus TUF GAMING 13 0" AMD Ryzen 7 3800X 3 9 GHz CPU 1 TB Internal Hard Drive 18 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Asus 13 0" laptop 18 GB ram 5 TB Hard Drive AMD Ryzen 7 3800X CPU
# 2.  Asus TUF GAMING 13 0 inch AMD Ryzen 7 3800X CPU 18 GB memory 1 TB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  TUF GAMING 13 0 inch 18 GB memory AMD Ryzen 7 3800X 3 9 GHz 5 TB Hard Drive
# 2.  Asus TUF GAMING 13 0" AMD Ryzen 7 3800X 3 9 GHz CPU 1 TB Internal Hard Drive 18 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP Chromebook 12 3 inch laptop 4 TB SSD 26 GB memory Intel Celeron Dual N3050 CPU
# 2.  HP 12 3" 26 GB memory Intel Celeron Dual Core N3050 1 6GHz 4 TB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Pavilion 12 3" laptop Celeron Dual N3050 1 6GHz CPU 26 GB ram 4 TB SATA SSD
# 2.  HP Pavilion 12 3" laptop Intel Celeron Dual Core N3050 26 GB memory 4 TB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP Chromebook 12 3 inch laptop 4 TB SSD 26 GB memory Intel Celeron Dual N3050 CPU
# 2.  Pavilion 12 3" laptop Celeron Dual N3050 1 6GHz CPU 26 GB ram 4 TB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  HP 12 3" 26 GB memory Intel Celeron Dual Core N3050 1 6GHz 4 TB SSD
# 2.  HP Pavilion 12 3" laptop Intel Celeron Dual Core N3050 26 GB memory 4 TB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Acer 10 1" laptop 6 GB memory Intel Core i7 9700F 272 GB HDD
# 2.  Acer 10 1 inch 6 GB memory 272 GB Hard Drive Intel Core i7 9700F CPU
# Label:  1
# ----------------------------------------------------
# 1.  Acer Travelmate 10 1 inch 6 GB ram 272 GB Hard Drive AMD A4 Series 7210
# 2.  Acer Travelmate 10 1" 6 GB memory AMD A4 Series 7210 272 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 10 1" laptop 6 GB memory Intel Core i7 9700F 272 GB HDD
# 2.  Acer Travelmate 10 1 inch 6 GB ram 272 GB Hard Drive AMD A4 Series 7210
# Label:  0
# ----------------------------------------------------
# 1.  Acer 10 1 inch 6 GB memory 272 GB Hard Drive Intel Core i7 9700F CPU
# 2.  Acer Travelmate 10 1" 6 GB memory AMD A4 Series 7210 272 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Asus 18 4" laptop Intel Core i7 7500U 264 GB Internal Hard Drive 92 GB ram
# 2.  Asus ROG 18 4" Intel Core i7 7500U CPU 264 GB HDD 92 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Asus ROG 18 4" laptop 264 GB Hard Drive 62 GB memory i7 7500U 2 7GHz
# 2.  ROG 18 4" 62 GB memory 264 GB Internal Hard Drive Core i7 7500U
# Label:  1
# ----------------------------------------------------
# 1.  Asus 18 4" laptop Intel Core i7 7500U 264 GB Internal Hard Drive 92 GB ram
# 2.  Asus ROG 18 4" laptop 264 GB Hard Drive 62 GB memory i7 7500U 2 7GHz
# Label:  0
# ----------------------------------------------------
# 1.  Asus ROG 18 4" Intel Core i7 7500U CPU 264 GB HDD 92 GB memory
# 2.  ROG 18 4" 62 GB memory 264 GB Internal Hard Drive Core i7 7500U
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 10 1 inch laptop 432 GB Internal Hard Drive AMD Ryzen 5 1400 3 2 GHz CPU 64 GB memory
# 2.  Lenovo 10 1 inch Ryzen 5 1400 432 GB Hard Drive 64 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 13 5" laptop AMD Ryzen 5 1400 4 Core 3 2 GHz 64 GB ram 432 GB Hard Drive
# 2.  Lenovo Yoga 13 5 inch laptop AMD Ryzen 5 1400 3 2 GHz 64 GB memory 432 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 10 1 inch laptop 432 GB Internal Hard Drive AMD Ryzen 5 1400 3 2 GHz CPU 64 GB memory
# 2.  Lenovo 13 5" laptop AMD Ryzen 5 1400 4 Core 3 2 GHz 64 GB ram 432 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 10 1 inch Ryzen 5 1400 432 GB Hard Drive 64 GB memory
# 2.  Lenovo Yoga 13 5 inch laptop AMD Ryzen 5 1400 3 2 GHz 64 GB memory 432 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Aspire 12 0 inch laptop AMD Ryzen 5 3600 82 GB memory 3 TB SSD
# 2.  Aspire 12 0" AMD Ryzen 5 3600 82 GB memory 3 TB Solid State Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Aspire 12 0" 82 GB memory 224 GB SATA SSD Ryzen 5 3600 CPU
# 2.  Acer 12 0 inch 224 GB M 2 SSD 82 GB ram AMD Ryzen 5 3600 6 Core CPU
# Label:  1
# ----------------------------------------------------
# 1.  Acer Aspire 12 0 inch laptop AMD Ryzen 5 3600 82 GB memory 3 TB SSD
# 2.  Acer Aspire 12 0" 82 GB memory 224 GB SATA SSD Ryzen 5 3600 CPU
# Label:  0
# ----------------------------------------------------
# 1.  Aspire 12 0" AMD Ryzen 5 3600 82 GB memory 3 TB Solid State Drive
# 2.  Acer 12 0 inch 224 GB M 2 SSD 82 GB ram AMD Ryzen 5 3600 6 Core CPU
# Label:  0
# ----------------------------------------------------
# 1.  Apple 12 3 inch laptop 20 GB memory 432 GB M 2 SSD A12 Series 9700P
# 2.  Apple 12 3 inch laptop AMD A12 Series 9700P CPU 20 GB ram 432 GB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 12 3 inch A12 Series 9700P 20 GB ram 432 GB Solid State Drive
# 2.  Spin 12 3 inch laptop AMD A12 Series 9700P 2 5GHz 432 GB SSD 20 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Apple 12 3 inch laptop 20 GB memory 432 GB M 2 SSD A12 Series 9700P
# 2.  Acer 12 3 inch A12 Series 9700P 20 GB ram 432 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Apple 12 3 inch laptop AMD A12 Series 9700P CPU 20 GB ram 432 GB SSD
# 2.  Spin 12 3 inch laptop AMD A12 Series 9700P 2 5GHz 432 GB SSD 20 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell Alienware 13 3 inch 456 GB Solid State Drive 46 GB memory Intel Xeon E3 1535M v5 2 9GHz
# 2.  Dell 13 3 inch laptop 46 GB memory 456 GB M 2 SSD Intel Xeon E3 1535M v5
# Label:  1
# ----------------------------------------------------
# 1.  Dell Alienware 13 3 inch laptop 456 GB SATA SSD 46 GB ram Intel Core i9 9900K 8 Core
# 2.  Dell 13 3" laptop 46 GB ram 456 GB SATA SSD Intel Core i9 9900K 8 Core
# Label:  1
# ----------------------------------------------------
# 1.  Dell Alienware 13 3 inch 456 GB Solid State Drive 46 GB memory Intel Xeon E3 1535M v5 2 9GHz
# 2.  Dell Alienware 13 3 inch laptop 456 GB SATA SSD 46 GB ram Intel Core i9 9900K 8 Core
# Label:  0
# ----------------------------------------------------
# 1.  Dell 13 3 inch laptop 46 GB memory 456 GB M 2 SSD Intel Xeon E3 1535M v5
# 2.  Dell 13 3" laptop 46 GB ram 456 GB SATA SSD Intel Core i9 9900K 8 Core
# Label:  0
# ----------------------------------------------------
# 1.  Aspire 13 5 inch Intel Celeron Quad N3710 5 TB HDD 126 GB memory
# 2.  Aspire 13 5" laptop 126 GB memory Intel Celeron Quad Core N3710 5 TB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Aspire 13 5 inch laptop 5 TB Hard Drive 102 GB ram Celeron Quad Core N3710 1 6GHz CPU
# 2.  Acer Aspire 13 5 inch Intel Celeron Quad Core N3710 CPU 5 TB Internal Hard Drive 102 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Aspire 13 5 inch Intel Celeron Quad N3710 5 TB HDD 126 GB memory
# 2.  Aspire 13 5 inch laptop 5 TB Hard Drive 102 GB ram Celeron Quad Core N3710 1 6GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Aspire 13 5" laptop 126 GB memory Intel Celeron Quad Core N3710 5 TB Internal Hard Drive
# 2.  Acer Aspire 13 5 inch Intel Celeron Quad Core N3710 CPU 5 TB Internal Hard Drive 102 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell Latitude 12 0" laptop 90 GB ram Intel Core i7 10700K 8 Core 3 8 GHz CPU 488 GB Internal Hard Drive
# 2.  Dell Latitude 12 0 inch laptop 90 GB memory 488 GB Internal Hard Drive Intel Core i7 10700K 8 Core 3 8 GHz
# Label:  1
# ----------------------------------------------------
# 1.  Dell Latitude 14 0 inch Intel Core i7 10700K 488 GB HDD 90 GB ram
# 2.  Dell Latitude 14 0 inch laptop Intel Core i7 10700K 8 Core CPU 488 GB HDD 90 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Dell Latitude 12 0" laptop 90 GB ram Intel Core i7 10700K 8 Core 3 8 GHz CPU 488 GB Internal Hard Drive
# 2.  Dell Latitude 14 0 inch Intel Core i7 10700K 488 GB HDD 90 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell Latitude 12 0 inch laptop 90 GB memory 488 GB Internal Hard Drive Intel Core i7 10700K 8 Core 3 8 GHz
# 2.  Dell Latitude 14 0 inch laptop Intel Core i7 10700K 8 Core CPU 488 GB HDD 90 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell 12 0 inch 100 GB ram Core i5 8600K CPU 472 GB Internal Hard Drive
# 2.  Dell XPS 12 0" laptop 100 GB ram Intel Core i5 8600K 3 6 GHz CPU 472 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  XPS 12 0" laptop 128 GB HDD Intel Core i5 8600K CPU 100 GB ram
# 2.  Dell XPS 12 0" i5 8600K 6 Core 100 GB memory 128 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Dell 12 0 inch 100 GB ram Core i5 8600K CPU 472 GB Internal Hard Drive
# 2.  XPS 12 0" laptop 128 GB HDD Intel Core i5 8600K CPU 100 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell XPS 12 0" laptop 100 GB ram Intel Core i5 8600K 3 6 GHz CPU 472 GB Internal Hard Drive
# 2.  Dell XPS 12 0" i5 8600K 6 Core 100 GB memory 128 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP 13 3 inch laptop Intel Core M 6Y54 CPU 5 TB SATA SSD 66 GB memory
# 2.  HP Probook 13 3" laptop 66 GB ram 5 TB Solid State Drive Intel M 6Y54 CPU
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 3" laptop Core M 6Y54 5 TB SATA SSD 66 GB memory
# 2.  Nitro 13 3" laptop Intel Core M 6Y54 1 1GHz CPU 5 TB SSD 66 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  HP 13 3 inch laptop Intel Core M 6Y54 CPU 5 TB SATA SSD 66 GB memory
# 2.  Acer 13 3" laptop Core M 6Y54 5 TB SATA SSD 66 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  HP Probook 13 3" laptop 66 GB ram 5 TB Solid State Drive Intel M 6Y54 CPU
# 2.  Nitro 13 3" laptop Intel Core M 6Y54 1 1GHz CPU 5 TB SSD 66 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP 15 4 inch 488 GB Solid State Drive 108 GB memory Intel Xeon E3 1535M v6
# 2.  HP ZBook 15 4" Intel Xeon E3 1535M v6 3 1GHz 488 GB SATA SSD 108 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  HP ZBook 15 4" A8 Series 7410 108 GB ram 488 GB M 2 SSD
# 2.  HP 15 4 inch laptop 488 GB SSD 108 GB memory AMD A8 Series 7410 2 2GHz CPU
# Label:  1
# ----------------------------------------------------
# 1.  HP 15 4 inch 488 GB Solid State Drive 108 GB memory Intel Xeon E3 1535M v6
# 2.  HP ZBook 15 4" A8 Series 7410 108 GB ram 488 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  HP ZBook 15 4" Intel Xeon E3 1535M v6 3 1GHz 488 GB SATA SSD 108 GB ram
# 2.  HP 15 4 inch laptop 488 GB SSD 108 GB memory AMD A8 Series 7410 2 2GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Dell 11 3 inch laptop 248 GB SATA SSD 30 GB ram Intel Core i7 4790K 4 GHz
# 2.  Dell 11 3" 30 GB memory Intel Core i7 4790K 4 Core 248 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Vostro 11 3" 94 GB ram Intel Core i7 4790K CPU 248 GB Solid State Drive
# 2.  Vostro 11 3" laptop Intel Core i7 4790K 94 GB memory 248 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell 11 3 inch laptop 248 GB SATA SSD 30 GB ram Intel Core i7 4790K 4 GHz
# 2.  Vostro 11 3" 94 GB ram Intel Core i7 4790K CPU 248 GB Solid State Drive
# Label:  0
# ----------------------------------------------------
# 1.  Dell 11 3" 30 GB memory Intel Core i7 4790K 4 Core 248 GB SATA SSD
# 2.  Vostro 11 3" laptop Intel Core i7 4790K 94 GB memory 248 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Extensa 13 5" laptop 200 GB Hard Drive 68 GB ram Intel Core i7 7820HK CPU
# 2.  Acer 13 5 inch 200 GB Internal Hard Drive 68 GB ram Intel Core i7 7820HK
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 13 0 inch Intel Core i7 7820HK 200 GB Hard Drive 68 GB ram
# 2.  Acer Extensa 13 0" Intel Core i7 7820HK CPU 200 GB Hard Drive 68 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Acer Extensa 13 5" laptop 200 GB Hard Drive 68 GB ram Intel Core i7 7820HK CPU
# 2.  Acer Extensa 13 0 inch Intel Core i7 7820HK 200 GB Hard Drive 68 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 5 inch 200 GB Internal Hard Drive 68 GB ram Intel Core i7 7820HK
# 2.  Acer Extensa 13 0" Intel Core i7 7820HK CPU 200 GB Hard Drive 68 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  HP 15 6 inch laptop i7 6500U CPU 86 GB ram 480 GB Internal Hard Drive
# 2.  HP 15 6" laptop Intel i7 6500U CPU 480 GB Internal Hard Drive 86 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  HP 15 6 inch laptop Intel Core i7 6500U CPU 280 GB Hard Drive 86 GB ram
# 2.  HP 15 6 inch 86 GB ram Core i7 6500U 2 5GHz 280 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 15 6 inch laptop i7 6500U CPU 86 GB ram 480 GB Internal Hard Drive
# 2.  HP 15 6 inch laptop Intel Core i7 6500U CPU 280 GB Hard Drive 86 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP 15 6" laptop Intel i7 6500U CPU 480 GB Internal Hard Drive 86 GB memory
# 2.  HP 15 6 inch 86 GB ram Core i7 6500U 2 5GHz 280 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 13 9" laptop AMD Threadripper 3970X 20 GB ram 392 GB HDD
# 2.  Lenovo 13 9 inch laptop 392 GB Internal Hard Drive Threadripper 3970X 32 Core 20 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Dell 13 9 inch 392 GB HDD Threadripper 3970X CPU 20 GB ram
# 2.  Dell 13 9 inch 392 GB HDD AMD Threadripper 3970X CPU 20 GB ram
# Label:  1
# ----------------------------------------------------
# ...
# 2.  Dell Precision 13 0" i7 7820HQ 2 9GHz 6 GB ram 440 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Dell 13 0 inch laptop 6 GB ram 312 GB Internal Hard Drive i7 7820HQ 2 9GHz
# 2.  Precision 13 0 inch laptop Intel Core i7 7820HQ 440 GB HDD 6 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  G Series 12 5" Core i3 9100F 4 Core 312 GB Hard Drive 86 GB memory
# 2.  Dell 12 5 inch 86 GB ram Intel Core i3 9100F 312 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  HP 12 5" Intel Core i3 9100F CPU 312 GB Hard Drive 86 GB memory
# 2.  HP Probook 12 5" 86 GB memory Intel i3 9100F 3 6 GHz 312 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  G Series 12 5" Core i3 9100F 4 Core 312 GB Hard Drive 86 GB memory
# 2.  HP 12 5" Intel Core i3 9100F CPU 312 GB Hard Drive 86 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Dell 12 5 inch 86 GB ram Intel Core i3 9100F 312 GB Hard Drive
# 2.  HP Probook 12 5" 86 GB memory Intel i3 9100F 3 6 GHz 312 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 5 inch laptop 192 GB Internal Hard Drive 72 GB ram Intel Xeon E3 1535M v5 CPU
# 2.  Acer Nitro 13 5" laptop Xeon E3 1535M v5 CPU 192 GB HDD 72 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Acer Nitro 13 5 inch 192 GB HDD Core i7 7820HQ 2 9GHz CPU 72 GB ram
# 2.  Nitro 13 5" laptop Intel i7 7820HQ CPU 72 GB ram 192 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer 13 5 inch laptop 192 GB Internal Hard Drive 72 GB ram Intel Xeon E3 1535M v5 CPU
# 2.  Acer Nitro 13 5 inch 192 GB HDD Core i7 7820HQ 2 9GHz CPU 72 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Acer Nitro 13 5" laptop Xeon E3 1535M v5 CPU 192 GB HDD 72 GB ram
# 2.  Nitro 13 5" laptop Intel i7 7820HQ CPU 72 GB ram 192 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Acer Switch 11 3" laptop 120 GB SATA SSD Intel i5 4690K 4 Core CPU 42 GB memory
# 2.  Switch 11 3" 42 GB ram i5 4690K CPU 120 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 11 3 inch 120 GB Solid State Drive Intel Core i5 4690K CPU 40 GB ram
# 2.  Acer Switch 11 3" laptop Intel Core i5 4690K CPU 40 GB memory 120 GB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer Switch 11 3" laptop 120 GB SATA SSD Intel i5 4690K 4 Core CPU 42 GB memory
# 2.  Acer 11 3 inch 120 GB Solid State Drive Intel Core i5 4690K CPU 40 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Switch 11 3" 42 GB ram i5 4690K CPU 120 GB SATA SSD
# 2.  Acer Switch 11 3" laptop Intel Core i5 4690K CPU 40 GB memory 120 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Spin 13 3 inch 34 GB memory Intel Core i3 6100U 2 3GHz 216 GB SATA SSD
# 2.  Spin 13 3" 216 GB SATA SSD 34 GB memory Intel i3 6100U 2 3GHz
# Label:  1
# ----------------------------------------------------
# 1.  Spin 18 4 inch Core i3 6100U 216 GB Solid State Drive 34 GB memory
# 2.  Acer 18 4 inch laptop 34 GB memory Intel Core i3 6100U 216 GB SATA SSD
# Label:  1
# ----------------------------------------------------
# 1.  Spin 13 3 inch 34 GB memory Intel Core i3 6100U 2 3GHz 216 GB SATA SSD
# 2.  Spin 18 4 inch Core i3 6100U 216 GB Solid State Drive 34 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Spin 13 3" 216 GB SATA SSD 34 GB memory Intel i3 6100U 2 3GHz
# 2.  Acer 18 4 inch laptop 34 GB memory Intel Core i3 6100U 216 GB SATA SSD
# Label:  0
# ----------------------------------------------------
# 1.  Acer Switch 11 3 inch Intel i9 10900X CPU 116 GB memory 456 GB HDD
# 2.  Acer 11 3 inch Intel i9 10900X 10 Core 116 GB memory 456 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Switch 11 3 inch laptop 144 GB Internal Hard Drive 116 GB memory Intel Core i9 10900X 10 Core 3 7 GHz CPU
# 2.  Acer Switch 11 3" i9 10900X 10 Core 116 GB memory 144 GB Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Switch 11 3 inch Intel i9 10900X CPU 116 GB memory 456 GB HDD
# 2.  Acer Switch 11 3 inch laptop 144 GB Internal Hard Drive 116 GB memory Intel Core i9 10900X 10 Core 3 7 GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Acer 11 3 inch Intel i9 10900X 10 Core 116 GB memory 456 GB Internal Hard Drive
# 2.  Acer Switch 11 3" i9 10900X 10 Core 116 GB memory 144 GB Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP 11 3 inch Intel i5 7Y57 120 GB memory 440 GB Internal Hard Drive
# 2.  HP 11 3" laptop 440 GB Internal Hard Drive Intel Core i5 7Y57 CPU 120 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo Yoga 11 3" 120 GB ram Core i5 7Y57 CPU 440 GB Internal Hard Drive
# 2.  Yoga 11 3 inch laptop 120 GB memory 440 GB Internal Hard Drive Intel Core i5 7Y57 1 2GHz CPU
# Label:  1
# ----------------------------------------------------
# 1.  HP 11 3 inch Intel i5 7Y57 120 GB memory 440 GB Internal Hard Drive
# 2.  Lenovo Yoga 11 3" 120 GB ram Core i5 7Y57 CPU 440 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  HP 11 3" laptop 440 GB Internal Hard Drive Intel Core i5 7Y57 CPU 120 GB memory
# 2.  Yoga 11 3 inch laptop 120 GB memory 440 GB Internal Hard Drive Intel Core i5 7Y57 1 2GHz CPU
# Label:  0
# ----------------------------------------------------
# 1.  Apple Mac 10 1 inch laptop 16 GB memory Core i5 6400 CPU 256 GB HDD
# 2.  Mac 10 1" laptop 16 GB memory Intel i5 6400 4 Core 256 GB HDD
# Label:  1
# ----------------------------------------------------
# 1.  Mac 10 1 inch laptop AMD Ryzen 3 3300X CPU 16 GB memory 256 GB Internal Hard Drive
# 2.  Mac 10 1" 256 GB Hard Drive AMD Ryzen 3 3300X CPU 16 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Apple Mac 10 1 inch laptop 16 GB memory Core i5 6400 CPU 256 GB HDD
# 2.  Mac 10 1 inch laptop AMD Ryzen 3 3300X CPU 16 GB memory 256 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Mac 10 1" laptop 16 GB memory Intel i5 6400 4 Core 256 GB HDD
# 2.  Mac 10 1" 256 GB Hard Drive AMD Ryzen 3 3300X CPU 16 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  HP 18 4 inch laptop Celeron Dual Core N3060 CPU 112 GB memory 416 GB SATA SSD
# 2.  ZBook 18 4 inch 112 GB memory 416 GB SSD Celeron Dual N3060 CPU
# Label:  1
# ----------------------------------------------------
# 1.  ZBook 18 4" 416 GB M 2 SSD Intel Celeron Dual N3060 1 6GHz CPU 40 GB memory
# 2.  ZBook 18 4" laptop 416 GB M 2 SSD 40 GB ram Intel Celeron Dual N3060 CPU
# Label:  1
# ----------------------------------------------------
# 1.  HP 18 4 inch laptop Celeron Dual Core N3060 CPU 112 GB memory 416 GB SATA SSD
# 2.  ZBook 18 4" 416 GB M 2 SSD Intel Celeron Dual N3060 1 6GHz CPU 40 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  ZBook 18 4 inch 112 GB memory 416 GB SSD Celeron Dual N3060 CPU
# 2.  ZBook 18 4" laptop 416 GB M 2 SSD 40 GB ram Intel Celeron Dual N3060 CPU
# Label:  0
# ----------------------------------------------------
# 1.  Acer Nitro 13 3" 104 GB memory 160 GB HDD Intel Core i7 6820HK
# 2.  Acer 13 3 inch laptop 104 GB ram 160 GB Internal Hard Drive Intel Core i7 6820HK 2 7GHz
# Label:  1
# ----------------------------------------------------
# 1.  Acer Nitro 14 1 inch laptop 160 GB Hard Drive 104 GB ram Intel Core i7 6820HK CPU
# 2.  Acer Nitro 14 1 inch laptop 160 GB Hard Drive 104 GB memory i7 6820HK CPU
# Label:  1
# ----------------------------------------------------
# 1.  Acer Nitro 13 3" 104 GB memory 160 GB HDD Intel Core i7 6820HK
# 2.  Acer Nitro 14 1 inch laptop 160 GB Hard Drive 104 GB ram Intel Core i7 6820HK CPU
# Label:  0
# ----------------------------------------------------
# 1.  Acer 13 3 inch laptop 104 GB ram 160 GB Internal Hard Drive Intel Core i7 6820HK 2 7GHz
# 2.  Acer Nitro 14 1 inch laptop 160 GB Hard Drive 104 GB memory i7 6820HK CPU
# Label:  0
# ----------------------------------------------------
# 1.  Asus Republic Gamers 11 6" laptop 432 GB Solid State Drive Intel Core i9 9900 8 Core CPU 108 GB memory
# 2.  Asus Republic Gamers 11 6" 108 GB memory 432 GB M 2 SSD Intel Core i9 9900 8 Core
# Label:  1
# ----------------------------------------------------
# 1.  Republic Gamers 11 6 inch 108 GB memory 440 GB M 2 SSD Intel i9 9900
# 2.  Asus 11 6" laptop Intel Core i9 9900 CPU 440 GB SATA SSD 108 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Asus Republic Gamers 11 6" laptop 432 GB Solid State Drive Intel Core i9 9900 8 Core CPU 108 GB memory
# 2.  Republic Gamers 11 6 inch 108 GB memory 440 GB M 2 SSD Intel i9 9900
# Label:  0
# ----------------------------------------------------
# 1.  Asus Republic Gamers 11 6" 108 GB memory 432 GB M 2 SSD Intel Core i9 9900 8 Core
# 2.  Asus 11 6" laptop Intel Core i9 9900 CPU 440 GB SATA SSD 108 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Apple 14 1" laptop 70 GB memory 224 GB Internal Hard Drive Intel Core i7 4790K 4 GHz CPU
# 2.  Apple 14 1" laptop 224 GB Hard Drive 70 GB ram Intel Core i7 4790K CPU
# Label:  1
# ----------------------------------------------------
# 1.  Apple 14 1" 70 GB memory 224 GB HDD Intel Core i7 4790K
# 2.  Apple 14 1 inch 224 GB HDD 70 GB ram Intel i7 4790K CPU
# Label:  1
# ----------------------------------------------------
# 1.  Apple 14 1" laptop 70 GB memory 224 GB Internal Hard Drive Intel Core i7 4790K 4 GHz CPU
# 2.  Apple 14 1" 70 GB memory 224 GB HDD Intel Core i7 4790K
# Label:  0
# ----------------------------------------------------
# 1.  Apple 14 1" laptop 224 GB Hard Drive 70 GB ram Intel Core i7 4790K CPU
# 2.  Apple 14 1 inch 224 GB HDD 70 GB ram Intel i7 4790K CPU
# Label:  0
# ----------------------------------------------------
# 1.  Dell 17 0 inch laptop 304 GB M 2 SSD Intel Core i3 6006U CPU 10 GB ram
# 2.  Dell Vostro 17 0 inch laptop Intel Core i3 6006U CPU 10 GB memory 304 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell 17 0 inch Intel i7 9700 3 GHz 10 GB memory 304 GB M 2 SSD
# 2.  Dell 17 0" laptop i7 9700 10 GB memory 304 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell 17 0 inch laptop 304 GB M 2 SSD Intel Core i3 6006U CPU 10 GB ram
# 2.  Dell 17 0 inch Intel i7 9700 3 GHz 10 GB memory 304 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Dell Vostro 17 0 inch laptop Intel Core i3 6006U CPU 10 GB memory 304 GB M 2 SSD
# 2.  Dell 17 0" laptop i7 9700 10 GB memory 304 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Apple Macbook Air 15 6 inch laptop Intel Core i3 2100 14 GB memory 264 GB Internal Hard Drive
# 2.  Apple 15 6 inch 264 GB Internal Hard Drive Intel i3 2100 14 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Apple 15 6" laptop 264 GB HDD Intel Core i3 2100 3 1 GHz 30 GB memory
# 2.  Apple 15 6" Intel i3 2100 264 GB Internal Hard Drive 30 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Apple Macbook Air 15 6 inch laptop Intel Core i3 2100 14 GB memory 264 GB Internal Hard Drive
# 2.  Apple 15 6" laptop 264 GB HDD Intel Core i3 2100 3 1 GHz 30 GB memory
# Label:  0
# ----------------------------------------------------
# 1.  Apple 15 6 inch 264 GB Internal Hard Drive Intel i3 2100 14 GB ram
# 2.  Apple 15 6" Intel i3 2100 264 GB Internal Hard Drive 30 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Asus 13 5 inch 160 GB Hard Drive Intel Pentium Quad Core N3700 24 GB ram
# 2.  Asus TUF GAMING 13 5" laptop Pentium Quad N3700 1 6GHz 160 GB Internal Hard Drive 24 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Asus 12 0 inch laptop Pentium Quad Core N3700 CPU 24 GB ram 160 GB HDD
# 2.  TUF GAMING 12 0 inch 24 GB ram 160 GB Hard Drive Intel Pentium Quad Core N3700 1 6GHz
# Label:  1
# ----------------------------------------------------
# 1.  Asus 13 5 inch 160 GB Hard Drive Intel Pentium Quad Core N3700 24 GB ram
# 2.  Asus 12 0 inch laptop Pentium Quad Core N3700 CPU 24 GB ram 160 GB HDD
# Label:  0
# ----------------------------------------------------
# 1.  Asus TUF GAMING 13 5" laptop Pentium Quad N3700 1 6GHz 160 GB Internal Hard Drive 24 GB memory
# 2.  TUF GAMING 12 0 inch 24 GB ram 160 GB Hard Drive Intel Pentium Quad Core N3700 1 6GHz
# Label:  0
# ----------------------------------------------------
# 1.  Dell 15 4 inch laptop Core i5 8250U 20 GB memory 240 GB M 2 SSD
# 2.  Dell 15 4 inch 240 GB SSD Intel Core i5 8250U 1 6GHz CPU 20 GB memory
# Label:  1
# ----------------------------------------------------
# 1.  Dell 15 4" 224 GB SATA SSD Intel Core i5 8250U 20 GB ram
# 2.  Dell 15 4 inch Intel Core i5 8250U 20 GB ram 224 GB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Dell 15 4 inch laptop Core i5 8250U 20 GB memory 240 GB M 2 SSD
# 2.  Dell 15 4" 224 GB SATA SSD Intel Core i5 8250U 20 GB ram
# Label:  0
# ----------------------------------------------------
# 1.  Dell 15 4 inch 240 GB SSD Intel Core i5 8250U 1 6GHz CPU 20 GB memory
# 2.  Dell 15 4 inch Intel Core i5 8250U 20 GB ram 224 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Asus 10 1 inch laptop Intel M M3 6Y30 CPU 352 GB Solid State Drive 10 GB memory
# 2.  Asus ROG 10 1" laptop Intel Core M M3 6Y30 10 GB ram 352 GB M 2 SSD
# Label:  1
# ----------------------------------------------------
# 1.  Acer 10 1" Intel M M3 6Y30 0 9GHz CPU 10 GB ram 352 GB M 2 SSD
# 2.  Acer 10 1" laptop Intel Core M M3 6Y30 0 9GHz CPU 10 GB memory 352 GB SSD
# Label:  1
# ----------------------------------------------------
# 1.  Asus 10 1 inch laptop Intel M M3 6Y30 CPU 352 GB Solid State Drive 10 GB memory
# 2.  Acer 10 1" Intel M M3 6Y30 0 9GHz CPU 10 GB ram 352 GB M 2 SSD
# Label:  0
# ----------------------------------------------------
# 1.  Asus ROG 10 1" laptop Intel Core M M3 6Y30 10 GB ram 352 GB M 2 SSD
# 2.  Acer 10 1" laptop Intel Core M M3 6Y30 0 9GHz CPU 10 GB memory 352 GB SSD
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo 11 3 inch laptop 120 GB SATA SSD Intel i3 2100 3 1 GHz 112 GB memory
# 2.  Lenovo ThinkPad 11 3 inch laptop 120 GB M 2 SSD Intel Core i3 2100 3 1 GHz CPU 112 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo ThinkPad 11 3 inch laptop 120 GB SSD 112 GB memory Intel i7 10700K CPU
# 2.  Lenovo 11 3" 120 GB M 2 SSD 112 GB memory Intel Core i7 10700K CPU
# Label:  1
# ----------------------------------------------------
# 1.  Lenovo 11 3 inch laptop 120 GB SATA SSD Intel i3 2100 3 1 GHz 112 GB memory
# 2.  Lenovo ThinkPad 11 3 inch laptop 120 GB SSD 112 GB memory Intel i7 10700K CPU
# Label:  0
# ----------------------------------------------------
# 1.  Lenovo ThinkPad 11 3 inch laptop 120 GB M 2 SSD Intel Core i3 2100 3 1 GHz CPU 112 GB ram
# 2.  Lenovo 11 3" 120 GB M 2 SSD 112 GB memory Intel Core i7 10700K CPU
# Label:  0
# ----------------------------------------------------
# 1.  Acer Aspire 15 4" laptop 416 GB Hard Drive Intel Core i9 9900KF 70 GB memory
# 2.  Aspire 15 4 inch laptop Intel Core i9 9900KF CPU 70 GB memory 416 GB Internal Hard Drive
# Label:  1
# ----------------------------------------------------
# 1.  Acer Aspire 15 4 inch laptop 34 GB ram Intel Core i9 9900KF 416 GB Internal Hard Drive
# 2.  Aspire 15 4" i9 9900KF CPU 416 GB Internal Hard Drive 34 GB ram
# Label:  1
# ----------------------------------------------------
# 1.  Acer Aspire 15 4" laptop 416 GB Hard Drive Intel Core i9 9900KF 70 GB memory
# 2.  Acer Aspire 15 4 inch laptop 34 GB ram Intel Core i9 9900KF 416 GB Internal Hard Drive
# Label:  0
# ----------------------------------------------------
# 1.  Aspire 15 4 inch laptop Intel Core i9 9900KF CPU 70 GB memory 416 GB Internal Hard Drive
# 2.  Aspire 15 4" i9 9900KF CPU 416 GB Internal Hard Drive 34 GB ram
# Label:  0
# ----------------------------------------------------
